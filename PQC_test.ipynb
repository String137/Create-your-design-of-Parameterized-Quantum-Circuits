# %%
from PQC import *

# %%
pqc = PQC("circ4c",4);

# %%
pqc.circ.draw('mpl')

# %% [markdown]
# # expressibility test

# %%
expressibility(pqc, 1000)
# Out:
# ---------------------------------------------------------------------------
# CircuitError                              Traceback (most recent call last)
# <ipython-input-4-dd2a056d2cb3> in <module>
# ----> 1 expressibility(pqc, 1000)
#
# ~/Create-your-design-of-Parameterized-Quantum-Circuits/PQC.py in expressibility(pqc, reps)
#     379     arr = [];
#     380     for i in range(reps):
# --> 381         v1 = pqc.get().getH();
#     382         v2 = pqc.get();
#     383         fid = np.abs(v1*v2)**2;
#
# ~/Create-your-design-of-Parameterized-Quantum-Circuits/PQC.py in get(self)
#     238             self.circ1 = self.circ.bind_parameters({self.theta1: np.random.uniform(0,2*np.pi,self.layer)});
#     239             self.circ2 = self.circ1.bind_parameters({self.theta2: np.random.uniform(0,2*np.pi,self.layer)});
# --> 240             self.circ3 = self.circ2.bind_parameters({self.theta3: np.random.uniform(0,2*np.pi,self.layer)});
#     241             result = execute(self.circ3,self.backend).result();
#     242             out_state = result.get_statevector();
#
# ~/opt/anaconda3/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py in bind_parameters(self, value_dict)
#    1908         if any(isinstance(value, ParameterExpression) for value in value_dict.values()):
#    1909             raise TypeError('Found ParameterExpression in values; use assign_parameters instead.')
# -> 1910         return self.assign_parameters(value_dict)
#    1911
#    1912     def _unroll_param_dict(self, value_dict):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py in assign_parameters(self, param_dict, inplace)
#    1881         # check that only existing parameters are in the parameter dictionary
#    1882         if unrolled_param_dict.keys() > self._parameter_table.keys():
# -> 1883             raise CircuitError('Cannot bind parameters ({}) not present in the circuit.'.format(
#    1884                 [str(p) for p in param_dict.keys() - self._parameter_table]))
#    1885
#
# CircuitError: 'Cannot bind parameters (["θ3, [\'θ3[0]\', \'θ3[1]\', \'θ3[2]\', \'θ3[3]\']"]) not present in the circuit.'

# %% [markdown]
# # entangling capability 계산

# %%
entangling_capability(pqc, 1000)
# Out:
# 100
#
# 200
#
# 300
#
# 400
#
# 500
#
# 600
#
# 700
#
# 800
#
# 900
# 0.3050271197454422

# %%
Circ4 =PQC("circ4", 4);

# %%
Circ4.circ.draw('mpl')

# %%
expressibility(Circ4, 1000)
# Out:
# 100
#
# 200
#
# 300
#
# 400
#
# 500
#
# 600
#
# 700
#
# 800
#
# 900
# C:\_QHackathon\myPQC.py:71: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(np.where(p*q != 0, p * np.log(p / q), 0));
# C:\_QHackathon\myPQC.py:71: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.where(p*q != 0, p * np.log(p / q), 0));
# C:\_QHackathon\myPQC.py:71: RuntimeWarning: invalid value encountered in multiply
#   return np.sum(np.where(p*q != 0, p * np.log(p / q), 0));
# 0.5288025246353685

# %%
entangling_capability(Circ4, 1000)
# Out:
# 0.07145327955800389
