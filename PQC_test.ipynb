# %%
from PQC import *

# %%
pqc = PQC("new1",4);

# %%
pqc.circ.draw('mpl')

# %%
print(pqc.get())
# Out:
# [[ 2.50000000e-01+2.50019737e-35j]
#  [ 3.37586936e-01-5.62616997e-02j]
#  [-2.08539110e-01-6.97353528e-02j]
#  [ 1.02405511e-02-7.73518972e-02j]
#  [ 3.37579589e-01+7.32883140e-02j]
#  [ 4.72343136e-01+2.29935038e-02j]
#  [ 2.73922442e-01+2.67041585e-01j]
#  [-7.45728797e-02+1.13427805e-01j]
#  [ 2.50000000e-01+0.00000000e+00j]
#  [ 3.37586936e-01-5.62616997e-02j]
#  [-2.08539110e-01-6.97353528e-02j]
#  [ 1.02405511e-02-7.73518972e-02j]
#  [-2.05291340e-04+7.52914489e-02j]
#  [ 1.66668848e-02+1.01715838e-01j]
#  [-4.44046594e-02+7.05716212e-02j]
#  [-2.75787881e-02-1.07138676e-02j]]

# %% [markdown]
# # expressibility test

# %%
expressibility(pqc, 1000)
# Out:
# 100
#
# 200
#
# 300
#
# 400
#
# 500
#
# 600
#
# 700
#
# 800
#
# 900
# 0.04556337428309824

# %% [markdown]
# # entangling capability 계산

# %%
entangling_capability(pqc, 1000)
# Out:
# C:\_QHackathon\myPQC.py:106: ComplexWarning: Casting complex values to real discards the imaginary part
#   newvec[new_index]=vec[int(original_index)];
# 3.5931007153364376e-33

# %%
Circ4 =PQC("circ4", 4);

# %%
Circ4.circ.draw('mpl')

# %%
expressibility(Circ4, 1000)
# Out:
# 100
#
# 200
#
# 300
#
# 400
#
# 500
#
# 600
#
# 700
#
# 800
#
# 900
# C:\_QHackathon\myPQC.py:71: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(np.where(p*q != 0, p * np.log(p / q), 0));
# C:\_QHackathon\myPQC.py:71: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.where(p*q != 0, p * np.log(p / q), 0));
# C:\_QHackathon\myPQC.py:71: RuntimeWarning: invalid value encountered in multiply
#   return np.sum(np.where(p*q != 0, p * np.log(p / q), 0));
# 0.5288025246353685

# %%
entangling_capability(Circ4, 1000)
# Out:
# 0.07145327955800389
