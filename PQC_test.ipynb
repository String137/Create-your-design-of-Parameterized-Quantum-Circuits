# %%
from PQC import *

# %%
pqc = PQC("circularcV",4);

# %%
pqc.circ.draw('mpl')

# %% [markdown]
# # expressibility test

# %%
expressibility(pqc, 1000)
# Out:
# 100
#
# 200
#
# 300
#
# 400
#
# 500
#
# 600
#
# 700
#
# 800
#
# 900
# 0.2877227567898215

# %% [markdown]
# # entangling capability 계산

# %%
entangling_capability(pqc, 10000)
# Out:
# 100
#
# 200
#
# 300
#
# 400
#
# 500
#
# 600
#
# 700
#
# 800
#
# 900
#
# 1000
#
# 1100
#
# 1200
#
# 1300
#
# 1400
#
# 1500
#
# 1600
#
# 1700
#
# 1800
#
# 1900
#
# 2000
#
# 2100
#
# 2200
#
# 2300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1151696dec1e> in <module>
# ----> 1 entangling_capability(pqc, 10000)
#
# ~/Create-your-design-of-Parameterized-Quantum-Circuits/PQC.py in entangling_capability(pqc, reps)
#     398     sum = 0;
#     399     for i in range(reps):
# --> 400         sum += Q(pqc.layer,pqc.get());
#     401         if i%100==0 and i!=0:
#     402             print(i,"\n");
#
# ~/Create-your-design-of-Parameterized-Quantum-Circuits/PQC.py in get(self)
#     237         if self.name =="circularcV":
#     238             self.circ1 = self.circ.bind_parameters({self.theta0: np.random.uniform(0,2*np.pi,self.layer)});
# --> 239             self.circ2 = self.circ1.bind_parameters({self.theta1: np.random.uniform(0,2*np.pi,self.layer)});
#     240             self.circ3 = self.circ2.bind_parameters({self.theta: np.random.uniform(0,np.pi,self.layer)});
#     241             self.circ4 = self.circ3.bind_parameters({self.phi: np.random.uniform(0,2*np.pi,self.layer)});
#
# ~/opt/anaconda3/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py in bind_parameters(self, value_dict)
#    1908         if any(isinstance(value, ParameterExpression) for value in value_dict.values()):
#    1909             raise TypeError('Found ParameterExpression in values; use assign_parameters instead.')
# -> 1910         return self.assign_parameters(value_dict)
#    1911
#    1912     def _unroll_param_dict(self, value_dict):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py in assign_parameters(self, param_dict, inplace)
#    1874         """
#    1875         # replace in self or in a copy depending on the value of in_place
# -> 1876         bound_circuit = self if inplace else self.copy()
#    1877
#    1878         # unroll the parameter dictionary (needed if e.g. it contains a ParameterVector)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py in copy(self, name)
#    1615                            for instr, _, __ in self._data}
#    1616
# -> 1617         instr_copies = {id_: instr.copy()
#    1618                         for id_, instr in instr_instances.items()}
#    1619
#
# ~/opt/anaconda3/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py in <dictcomp>(.0)
#    1615                            for instr, _, __ in self._data}
#    1616
# -> 1617         instr_copies = {id_: instr.copy()
#    1618                         for id_, instr in instr_instances.items()}
#    1619
#
# ~/opt/anaconda3/lib/python3.8/site-packages/qiskit/circuit/instruction.py in copy(self, name)
#     318             updated if it was provided
#     319         """
# --> 320         cpy = self.__deepcopy__()
#     321
#     322         if name:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/qiskit/circuit/controlledgate.py in __deepcopy__(self, _memo)
#     206         cpy.base_gate = self.base_gate.copy()
#     207         if self._definition:
# --> 208             cpy._definition = copy.deepcopy(self._definition, _memo)
#     209         return cpy
#     210
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_list(x, memo, deepcopy)
#     203     append = y.append
#     204     for a in x:
# --> 205         append(deepcopy(a, memo))
#     206     return y
#     207 d[list] = _deepcopy_list
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_tuple(x, memo, deepcopy)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in <listcomp>(.0)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_list(x, memo, deepcopy)
#     203     append = y.append
#     204     for a in x:
# --> 205         append(deepcopy(a, memo))
#     206     return y
#     207 d[list] = _deepcopy_list
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     136
#     137     d = id(x)
# --> 138     y = memo.get(d, _nil)
#     139     if y is not _nil:
#     140         return y
#
# KeyboardInterrupt:

# %%
Circ4 =PQC("circ4", 4);

# %%
Circ4.circ.draw('mpl')

# %%
expressibility(Circ4, 1000)
# Out:
# 100
#
# 200
#
# 300
#
# 400
#
# 500
#
# 600
#
# 700
#
# 800
#
# 900
# C:\_QHackathon\myPQC.py:71: RuntimeWarning: invalid value encountered in true_divide
#   return np.sum(np.where(p*q != 0, p * np.log(p / q), 0));
# C:\_QHackathon\myPQC.py:71: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.where(p*q != 0, p * np.log(p / q), 0));
# C:\_QHackathon\myPQC.py:71: RuntimeWarning: invalid value encountered in multiply
#   return np.sum(np.where(p*q != 0, p * np.log(p / q), 0));
# 0.5288025246353685

# %%
entangling_capability(Circ4, 1000)
# Out:
# 0.07145327955800389
